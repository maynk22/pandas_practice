# %%
import pandas as pd

# %%
df = pd.read_csv('./data/results.csv')
display(df)
# Out:
#           year    type              discipline                          event  \
# 0       1912.0  Summer                  Tennis         Singles, Men (Olympic)
# 1       1912.0  Summer                  Tennis         Doubles, Men (Olympic)
# 2       1920.0  Summer                  Tennis         Singles, Men (Olympic)
# 3       1920.0  Summer                  Tennis       Doubles, Mixed (Olympic)
# 4       1920.0  Summer                  Tennis         Doubles, Men (Olympic)
# ...        ...     ...                     ...                            ...
# 308403  2022.0  Winter                    Luge         Singles, Men (Olympic)
# 308404  2022.0  Winter  Alpine Skiing (Skiing)        Slalom, Women (Olympic)
# 308405  2022.0  Winter  Alpine Skiing (Skiing)          Team, Mixed (Olympic)
# 308406  2022.0  Winter  Alpine Skiing (Skiing)  Giant Slalom, Women (Olympic)
# 308407  2022.0  Winter                     NaN        Slalom, Women (Olympic)
#
# ...

# %%
#set_index(): It's used to set index/changed index.
#append = true, keep the original index in place and also add mentioned column as index.
#drop=False. it will not remove the original index, default value is true.
#inplace=True, it will modify the original df, default value is false which means creating a new df.
#df = df.set_index('type', append=True)
#display(df)

#reset_index(): Converts the index back to column.
#drop=True, removed the index completely instead of converting it inot column. Default value is false.
df = df.reset_index()
display(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 9
#       5 #df = df.set_index('type', append=True)
#       6 #display(df)
#       7
#       8 #reset_index():
# ----> 9 df = df.reset_index('type')
#      10 display(df)
#
# File ~/Desktop/mayank/practice/pandas-practice/pandas-tutorial/lib/python3.13/site-packages/pandas/core/frame.py:7272, in DataFrame.reset_index(self, level, drop, inplace, col_level, col_fill, allow_duplicates, names)
#    7268         new_index = default_index(len(new_obj))
#    7269         if level is not None:
#    7270             if not isinstance(level, (tuple, list)):
#    7271                 level = [level]
# -> 7272             level = [self.index._get_level_number(lev) for lev in level]
#    7273             if len(level) < self.index.nlevels:
#    7274                 new_index = self.index.droplevel(level)
#    7275
#
# ...
